# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

df = pd.read_excel (r'/content/SVT_Data.xlsx')
A = df["A"]
C = df["C"]
x = df['FCValue']
y = df['Difference']

# %%
csfont = {'fontname':'Humor Sans'}

plt.scatter(x, y, c='green', s=8)
plt.plot(A, C, c= "red", linestyle=':')
plt.legend(('Tolerance', 'Average Result'),
           loc='upper right')
plt.title('SVT Rep Results - everything', fontsize=26, **csfont)
plt.xlabel('Average Result', fontsize=15)
plt.ylabel('Difference', fontsize=15)
plt.gcf().set_size_inches(10, 7)
plt.grid(False)

plt.savefig('SVT.png', dpi=100)
plt.show()
